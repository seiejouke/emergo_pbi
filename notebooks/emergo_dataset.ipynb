# %%
import pyodbc
import pandas as pd

mdb_path = r"C:\Users\Jouke\Desktop\emergo_dataset\DemoDataBetsyBike.mdb"

conn_str = (
    r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
    fr"DBQ={mdb_path};"
)
conn = pyodbc.connect(conn_str)

# %%
cursor = conn.cursor()
tables = [row.table_name for row in cursor.tables(tableType='TABLE')]
print("Gevonden tabellen:", tables)
# Out:
# Gevonden tabellen: ['Address', 'Customer', 'Employee', 'Person', 'Product', 'ProductCategory', 'ProductModel', 'ProductSubcategory', 'ProductVendor', 'SalesOrderDetail', 'SalesOrderHeader', 'SalesTerritory', 'SalesTerritoryHistory', 'Store', 'Vendor']

# %%
dfs = {t: pd.read_sql(f"SELECT * FROM [{t}]", conn) for t in tables}
#conn.close()
# Out:
# C:\Users\Jouke\AppData\Local\Temp\ipykernel_46048\165661988.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfs = {t: pd.read_sql(f"SELECT * FROM [{t}]", conn) for t in tables}

# %%
df_sales_detail = dfs['SalesOrderDetail']
df_sales_detail.info()
df_sales_detail.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119108 entries, 0 to 119107
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   SalesOrderID           119108 non-null  float64
#  1   SalesOrderDetailID     119108 non-null  float64
#  2   ProductID              119108 non-null  float64
#  3   SpecialOfferID         119108 non-null  float64
#  4   UnitPrice              119108 non-null  float64
#  5   OrderQty               119108 non-null  float64
#  6   UnitPriceDiscount      119108 non-null  float64
#  7   CarrierTrackingNumber  60919 non-null   object
#  8   DueDate                119108 non-null  datetime64[ns]
#  9   ShipDate               119108 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(7), object(1)
# memory usage: 9.1+ MB
# SalesOrderID                 0
# SalesOrderDetailID           0
# ProductID                    0
# SpecialOfferID               0
# ...

# %%
df_sales_header = dfs['SalesOrderHeader']
df_sales_header.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30489 entries, 0 to 30488
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SalesOrderID         30489 non-null  int64
#  1   RevisionNumber       30489 non-null  int64
#  2   OrderDate            30489 non-null  datetime64[ns]
#  3   Status               30489 non-null  int64
#  4   OnlineOrderFlag      30489 non-null  bool
#  5   SalesOrderNumber     30489 non-null  object
#  6   PurchaseOrderNumber  3806 non-null   object
#  7   AccountNumber        30489 non-null  object
#  8   CustomerID           30489 non-null  int64
#  9   TerritoryID          30489 non-null  int64
#  10  BillToAddressID      30489 non-null  int64
#  11  ShipToAddressID      30489 non-null  int64
#  12  ShipMethodID         30489 non-null  int64
#  13  TaxAmt               30489 non-null  float64
#  14  Freight              30489 non-null  float64
# ...

# %%
df_product_vendor = dfs['ProductVendor']
df_product_vendor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ProductID         457 non-null    int64
#  1   BusinessEntityID  457 non-null    int64
#  2   AverageLeadTime   457 non-null    int64
#  3   StandardPrice     457 non-null    float64
#  4   LastReceiptCost   457 non-null    float64
#  5   LastReceiptDate   457 non-null    datetime64[ns]
#  6   MinOrderQty       457 non-null    int64
#  7   MaxOrderQty       457 non-null    int64
#  8   OnOrderQty        155 non-null    float64
#  9   UnitMeasureCode   457 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(1)
# memory usage: 35.8+ KB

# %%
df_product_sub_cat = dfs['ProductSubcategory']
df_product_sub_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductSubcategoryID  37 non-null     int64
#  1   ProductCategoryID     37 non-null     int64
#  2   Name                  37 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 1020.0+ bytes

# %%
df_product_model = dfs['ProductModel']
df_product_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductModelID  128 non-null    int64
#  1   Name            128 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.1+ KB

# %%
df_product_cat = dfs['ProductCategory']
df_product_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductCategoryID  4 non-null      int64
#  1   Name               4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df_product = dfs['Product']
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductID              504 non-null    int64
#  1   Name                   504 non-null    object
#  2   ProductNumber          504 non-null    object
#  3   MakeFlag               504 non-null    bool
#  4   FinishedGoodsFlag      504 non-null    bool
#  5   Color                  256 non-null    object
#  6   SafetyStockLevel       504 non-null    int64
#  7   ReorderPoint           504 non-null    int64
#  8   StandardCost           504 non-null    float64
#  9   ListPrice              504 non-null    float64
#  10  Size                   211 non-null    object
#  11  SizeUnitMeasureCode    176 non-null    object
#  12  WeightUnitMeasureCode  205 non-null    object
#  13  Weight                 205 non-null    float64
# ...

# %%
df_person = dfs['Person']
df_person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19972 entries, 0 to 19971
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BusinessEntityID  19972 non-null  float64
#  1   PersonType        19972 non-null  object
#  2   NameStyle         19972 non-null  float64
#  3   Title             1009 non-null   object
#  4   FirstName         19972 non-null  object
#  5   MiddleName        11473 non-null  object
#  6   LastName          19972 non-null  object
#  7   Suffix            53 non-null     object
#  8   EmailPromotion    19972 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 1.4+ MB

# %%
df_employee = dfs['Employee']
df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   EmployeeBusinessEntityID        296 non-null    int64
#  1   ParentEmployeeBusinessEntityID  295 non-null    float64
#  2   FirstName                       296 non-null    object
#  3   LastName                        296 non-null    object
#  4   MiddleName                      283 non-null    object
#  5   Title                           296 non-null    object
#  6   SalesTerritoryKey               296 non-null    int64
#  7   HireDate                        296 non-null    datetime64[ns]
#  8   BirthDate                       296 non-null    datetime64[ns]
#  9   EmailAddress                    296 non-null    object
#  10  Phone                           296 non-null    object
#  11  MaritalStatus                   296 non-null    object
# ...

# %%
df_customer = dfs['Customer']
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19820 entries, 0 to 19819
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     19820 non-null  int64
#  1   PersonID       19119 non-null  float64
#  2   StoreID        1336 non-null   float64
#  3   TerritoryID    19820 non-null  int64
#  4   AccountNumber  19820 non-null  object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 774.3+ KB

# %%
df_address = dfs['Address']
df_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19614 entries, 0 to 19613
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AddressID                19614 non-null  int64
#  1   AddressLine1             19614 non-null  object
#  2   AddressLine2             362 non-null    object
#  3   City                     19614 non-null  object
#  4   PostalCode               19614 non-null  object
#  5   StateProvinceCode        19614 non-null  object
#  6   CountryRegionCode        19614 non-null  object
#  7   IsOnlyStateProvinceFlag  19614 non-null  bool
#  8   StateProvinceName        19614 non-null  object
#  9   TerritoryID              19614 non-null  int64
#  10  CountryRegionName        19614 non-null  object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 1.5+ MB

# %%
df_vendor = dfs['Vendor']
df_vendor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   BusinessEntityID       104 non-null    int64
#  1   AccountNumber          104 non-null    object
#  2   Name                   104 non-null    object
#  3   CreditRating           104 non-null    int64
#  4   PreferredVendorStatus  104 non-null    bool
#  5   ActiveFlag             104 non-null    bool
# dtypes: bool(2), int64(2), object(2)
# memory usage: 3.6+ KB

# %%
df_store = dfs['Store']
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreID        701 non-null    float64
#  1   StoreName      701 non-null    object
#  2   SalesPersonID  701 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 16.6+ KB

# %%
df_sales_territory_history = dfs['SalesTerritoryHistory']
df_sales_territory_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BusinessEntityID  14 non-null     int64
#  1   TerritoryID       14 non-null     int64
#  2   StartDate         14 non-null     datetime64[ns]
#  3   EndDate           4 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(2)
# memory usage: 580.0 bytes

# %%
df_sales_territory = dfs['SalesTerritory']
df_sales_territory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TerritoryID        10 non-null     int64
#  1   Name               10 non-null     object
#  2   CountryRegionCode  10 non-null     object
#  3   Group              10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
dfs.keys()
# Out:
# dict_keys(['Address', 'Customer', 'Employee', 'Person', 'Product', 'ProductCategory', 'ProductModel', 'ProductSubcategory', 'ProductVendor', 'SalesOrderDetail', 'SalesOrderHeader', 'SalesTerritory', 'SalesTerritoryHistory', 'Store', 'Vendor'])
