# %%
import pyodbc
import pandas as pd

mdb_path = r"C:\Users\Jouke\Desktop\Emergo Dataset\DemoDataSet.mdb"

conn_str = (
    r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
    fr"DBQ={mdb_path};"
)
conn = pyodbc.connect(conn_str)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 10
#       4 mdb_path = r"C:\Users\Jouke\Desktop\Emergo Dataset\DemoDataSet.mdb"
#       6 conn_str = (
#       7     r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
#       8     fr"DBQ={mdb_path};"
#       9 )
# ---> 10 conn = pyodbc.connect(conn_str)
#
# ...
